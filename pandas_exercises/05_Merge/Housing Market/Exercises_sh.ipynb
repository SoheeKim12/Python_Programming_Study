# %% [markdown]
# <a href="https://colab.research.google.com/github/SoheeKim12/Python_Programming_Study/blob/main/pandas_exercises/05_Merge/Housing%20Market/Exercises_sh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Housing Market

# %% [markdown]
# ### Introduction:
#
# This time we will create our own dataset with fictional numbers to describe a house market. As we are going to create random data don't try to reason of the numbers.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Create 3 differents Series, each of length 100, as follows:
# 1. The first a random number from 1 to 4
# 2. The second a random number from 1 to 3
# 3. The third a random number from 10,000 to 30,000

# %%
series1 = pd.Series(np.random.randint(1, 5, size=100)) # randint: 임의의 정수 생성
series2 = pd.Series(np.random.randint(1, 4, size=100))
series3 = pd.Series(np.random.randint(10000, 30001, size=100))

# %%
series3
# Out:
# 0     23041
# 1     14266
# 2     23448
# 3     20258
# 4     27655
#       ...
# 95    29967
# 96    17308
# 97    18608
# 98    19987
# 99    15954
# Length: 100, dtype: int64

# %% [markdown]
# ### Step 3. Let's create a DataFrame by joinning the Series by column

# %%
# df = pd.DataFrame({'0':series1, '1':series2, '2':series3})

# %%
df = pd.concat([series1, series2, series3], axis=1)

# %%
df.head()
# Out:
#    0  1      2
# 0  4  3  23041
# 1  4  1  14266
# 2  3  1  23448
# 3  2  1  20258
# 4  2  2  27655

# %% [markdown]
# ### Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df.columns = (['bedrs', 'bathrs', 'price_sqr_meter'])

# %%
df.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      4       3            23041
# 1      4       1            14266
# 2      3       1            23448
# 3      2       1            20258
# 4      2       2            27655

# %% [markdown]
# ### Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
#bicolumn = pd.concat([pd.Series(series1), pd.Series(series2), pd.Series(series3)], axis=0)

# %%
bigcolumn = pd.concat([series1, series2, series3], axis=0)

# %%
# Set the display option to show all rows and columns without truncation
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns (if you have multiple columns)
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to a new line

bicolumn
# Out:
# 0         4
# 1         4
# 2         3
# 3         2
# 4         2
# 5         2
# 6         2
# 7         3
# 8         1
# 9         1
# 10        4
# 11        4
# 12        3
# 13        4
# 14        2
# 15        1
# 16        4
# 17        3
# 18        1
# 19        1
# 20        1
# 21        4
# 22        2
# 23        1
# 24        4
# 25        1
# 26        1
# 27        3
# 28        1
# 29        3
# 30        3
# 31        2
# 32        3
# 33        4
# 34        2
# 35        1
# 36        3
# 37        2
# 38        2
# 39        4
# 40        3
# 41        3
# 42        3
# 43        2
# 44        4
# 45        3
# 46        2
# 47        3
# 48        3
# 49        1
# 50        1
# 51        2
# 52        4
# 53        2
# 54        3
# 55        4
# 56        1
# 57        2
# 58        3
# 59        3
# 60        4
# 61        3
# 62        2
# 63        2
# 64        4
# 65        4
# 66        4
# 67        1
# 68        2
# 69        2
# 70        1
# ...

# %% [markdown]
# ### Step 6. Oops, it seems it is going only until index 99. Is it true?

# %%
len(bigcolumn)
# Out:
# 300

# %% [markdown]
# ### Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bicolumn = bicolumn.reset_index(drop=True) # drop: 기존 인덱스 제거

bicolumn
# Out:
# 0          4
# 1          4
# 2          3
# 3          2
# 4          2
# 5          2
# 6          2
# 7          3
# 8          1
# 9          1
# 10         4
# 11         4
# 12         3
# 13         4
# 14         2
# 15         1
# 16         4
# 17         3
# 18         1
# 19         1
# 20         1
# 21         4
# 22         2
# 23         1
# 24         4
# 25         1
# 26         1
# 27         3
# 28         1
# 29         3
# 30         3
# 31         2
# 32         3
# 33         4
# 34         2
# 35         1
# 36         3
# 37         2
# 38         2
# 39         4
# 40         3
# 41         3
# 42         3
# 43         2
# 44         4
# 45         3
# 46         2
# 47         3
# 48         3
# 49         1
# 50         1
# 51         2
# 52         4
# 53         2
# 54         3
# 55         4
# 56         1
# 57         2
# 58         3
# 59         3
# 60         4
# 61         3
# 62         2
# 63         2
# 64         4
# 65         4
# ...
