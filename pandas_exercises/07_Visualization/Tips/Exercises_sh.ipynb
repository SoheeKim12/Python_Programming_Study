# %% [markdown]
# <a href="https://colab.research.google.com/github/SoheeKim12/Python_Programming_Study/blob/main/pandas_exercises/07_Visualization/Tips/Exercises_sh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd

# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# 결과물을 해당 브라우저에서 바로 볼 수 있게 해주는 코드
% matplotlib inline

# set seaborn style to white
sns.set_style("white")
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv'

tips = pd.read_csv(url)

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips['Unnamed: 0']

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
# create histogram
ttbill = sns.distplot(tips.total_bill);

# set lables and titles
ttbill.set(xlabel = 'Value', ylabel = 'Frequency', title = "Total Bill")

# take out the right and upper borders -> 그래프의 오른쪽과 위쪽 테두리를 제거해 깔끔한 시각화, (!이 코드 안돌려도 테두리 없음)
sns.despine()
# Out:
# <ipython-input-10-3a41aba31414>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ttbill = sns.distplot(tips.total_bill);
# [Text(0.5, 0, 'Value'),
#  Text(0, 0.5, 'Frequency'),
#  Text(0.5, 1.0, 'Total Bill')]

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# jointplot은 두 변수 간의 관계를 시각화, 산점도와 히스토그램을 결합하여 두 변수의 상관관계와 각각의 분포를 동시에 보여줌
# 기본 형태: sns.jointplot(x="변수1", y="변수2", data=데이터셋)

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.pairplot(tips)

# pairplot은 여러 변수 간의 관계를 한 번에 시각화하는 데 유용한 기능을 제공, 데이터셋 내의 모든 수치형 변수 쌍에 대해 산점도 또는 다양한 플롯을 그림.
# 기본 형태: sns.pairplot(data=데이터셋)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.stripplot(x = "day", y = "total_bill", data = tips, jitter = True, hue="day", palette="Set2")

# stripplot은 범주형 데이터를 시각화할 때 사용하는 함수로, 범주형 변수와 연속형 변수 간의 관계를 보여줌, 각 데이터 포인트를 점으로 표시하여 분포와 밀집도를 시각적으로 파악하는 데 유용
# 기본 형태: sns.stripplot(x="범주형_변수", y="연속형_변수", data=데이터셋)
# hue, palette 옵션으로 색상을 다르게 적용할 수 있음.
# jitter = True 데이터 포인트가 겹치는 것을 방지하기 위해 데이터를 살짝 흩뿌려주는 역할
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %% [markdown]
# day를 y축으로, tip을 x축으로 하여 산점도를 만들고 sex에 따라 점을 다르게 표시하여 산점도를 그려라

# %%
sns.stripplot(x = "tip", y = "day", hue = "sex", data = tips, jitter = True);

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %% [markdown]
# time(Dinner or Lunch)에 따라 하루 total_bill을 나타내는 box plot

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "time", data = tips);

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %% [markdown]
# 디너와 런치를를 기준으로 tip 값에 대한 두 개의 히스토그램, 나란히

# %%
# better seaborn style
sns.set(style = "ticks")

# creates FacetGrid
g = sns.FacetGrid(tips, col = "time")
g.map(plt.hist, "tip");

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.
#
# 흡연자 또는 비흡연자에 따라 달라지는 total_bill 값과 팁 관계를 나타내는 남성과 여성에 대한 두 개의 산점도 그래프

# %%
g = sns.FacetGrid(tips, col = "sex", hue = "smoker")
g.map(plt.scatter, "total_bill", "tip", alpha =.7)

g.add_legend();

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
