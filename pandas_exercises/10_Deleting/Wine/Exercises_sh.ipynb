# %% [markdown]
# <a href="https://colab.research.google.com/github/SoheeKim12/Python_Programming_Study/blob/main/pandas_exercises/10_Deleting/Wine/Exercises_sh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

wine = pd.read_csv(url, sep=',')
wine
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
# 열 삭제
delete = [0, 3, 6, 8, 10, 12, 13]

wine = wine.drop(wine.columns[delete], axis=1)
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine = wine.set_axis(labels=['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue'], axis=1)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.loc[10:29, ['alcohol']] = np.nan

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
# magnesium열의 3, 4번째 행을 NaN으로

wine.loc[2:3, 'magnesium'] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2      100.0        2.76
# 1    13.16        2.36               18.6      101.0        3.24
# 2    14.37        1.95               16.8        NaN        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
# alcohol열의 NaN 값을 10으로, magnesium열의 NaN값을 100으로

wine['alcohol'].fillna(10, inplace=True)

wine['magnesium'].fillna(100, inplace=True)

wine
# Out:
# <ipython-input-41-09da741d94fd>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wine['alcohol'].fillna(10, inplace=True)
# <ipython-input-41-09da741d94fd>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
np.random.randint(0, 11, size=10)
# Out:
# array([6, 5, 4, 9, 0, 7, 3, 0, 4, 6])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
# 랜덤 숫자를 생성하고 해당 인덱스를 NaN으로

rand = np.random.randint(0, 11, size=10)
rand
# Out:
# array([ 9,  7,  8,  9,  3,  9,  6,  0, 10,  2])

# %%
# 랜덤 숫자를 인덱스로 사용해 결측치(NaN) 할당
for idx in rand:
    if idx < len(wine):  # 인덱스가 데이터프레임 길이 내에 있는지 확인
        wine.loc[idx, :] = np.NaN

wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN         NaN                NaN        NaN         NaN
# 1      13.16        2.36               18.6      101.0        3.24
# 2        NaN         NaN                NaN        NaN         NaN
# 3        NaN         NaN                NaN        NaN         NaN
# 4      14.20        1.76               15.2      112.0        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0                NaN   NaN
# 1               2.81  1.03
# 2                NaN   NaN
# 3                NaN   NaN
# ...

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isnull().sum()
# Out:
# alcohol              8
# malic_acid           8
# alcalinity_of_ash    8
# magnesium            8
# flavanoids           8
# proanthocyanins      8
# hue                  8
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
a = wine.dropna()
a
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 1      13.16        2.36               18.6      101.0        3.24
# 4      14.20        1.76               15.2      112.0        3.39
# 5      14.39        1.87               14.6       96.0        2.52
# 11     10.00        1.73               16.0       89.0        2.76
# 12     10.00        1.73               11.4       91.0        3.69
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 1               2.81  1.03
# 4               1.97  1.05
# 5               1.98  1.02
# 11              1.81  1.15
# ...

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
 # 질문 이해 못함
 wine[wine['alcohol'] == 0]
# Out:
# Empty DataFrame
# Columns: [alcohol, malic_acid, alcalinity_of_ash, magnesium, flavanoids, proanthocyanins, hue]
# Index: []

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
a.reset_index(drop=True)
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      13.16        2.36               18.6      101.0        3.24
# 1      14.20        1.76               15.2      112.0        3.39
# 2      14.39        1.87               14.6       96.0        2.52
# 3      10.00        1.73               16.0       89.0        2.76
# 4      10.00        1.73               11.4       91.0        3.69
# ..       ...         ...                ...        ...         ...
# 164    13.71        5.65               20.5       95.0        0.61
# 165    13.40        3.91               23.0      102.0        0.75
# 166    13.27        4.28               20.0      120.0        0.69
# 167    13.17        2.59               20.0      120.0        0.68
# 168    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.81  1.03
# 1               1.97  1.05
# 2               1.98  1.02
# 3               1.81  1.15
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
